# %%
# i am learning skearn library
from sklearn import linear_model as lm
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv("homeprises.csv")
plt.scatter(df.area,df.price,color='red',marker='+')
plt.grid()
plt.show()

# %%
new_df= df.drop(["price","bedrooms"], axis='columns')
price= df.price
new_df
# Out:
#    area
# 0   500
# 1   600
# 2   700
# 3   800
# 4   900
# 5  1000

# %%
model= lm.LinearRegression()
model.fit(new_df, df.price)
# Out:
# LinearRegression()

# %%
model.predict([[1100]])
# Out:
# d:\coding\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([291333.33333333])

# %% [markdown]
# # exercise

# %%
df_2=pd.read_csv("canada_per_capita_income.csv")
df_2.head()
# Out:
#    year  per_capita_income
# 0  1970        3399.299037
# 1  1971        3768.297935
# 2  1972        4251.175484
# 3  1973        4804.463248
# 4  1974        5576.514583

# %%
plt.scatter(df_2.year,df_2.per_capita_income,color='red',marker='+')
plt.grid()
plt.show()

# %%
model_2=lm.LinearRegression()
model_2.fit(df_2[['year']], df_2.per_capita_income)
# Out:
# LinearRegression()

# %%
model_2.predict([[2020]])
# Out:
# d:\coding\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([41288.69409442])
